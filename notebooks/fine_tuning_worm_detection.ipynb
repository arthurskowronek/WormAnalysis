# %%
# !pip install ultralytics==8.3.127 roboflow torch==2.0.1 torchvision==0.15.2 torchaudio==2.0.1
# Out:
# /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/V2/.venv/bin/pip: line 2: /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/.venv/bin/python: No such file or directory
# /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/V2/.venv/bin/pip: line 2: exec: /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/.venv/bin/python: cannot execute: No such file or directory

# %%
# !pip install torchvision==0.15.2
# Out:
# /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/V2/.venv/bin/pip: line 2: /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/.venv/bin/python: No such file or directory
# /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/V2/.venv/bin/pip: line 2: exec: /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/.venv/bin/python: cannot execute: No such file or directory

# %%
import torch
import torchvision

print("Torch version:", torch.__version__)
print("Torchvision version:", torchvision.__version__)
# Out:
# Torch version: 2.7.1
# Torchvision version: 0.22.1

# %%
from ultralytics import YOLO

# %%
from ultralytics import YOLO
import os

#model = YOLO("yolov8s.pt")  
#model = YOLO("../V2/runs11/detect/train/weights/best.pt")
model = YOLO("../models/YOLO_detection.pt")

current_directory = os.getcwd()
train_results = model.train(
    data = current_directory + "/YOLO_data/data.yaml",
    epochs=100,
    imgsz=1024,
    device="cpu",
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.235 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.170 🚀 Python-3.13.5 torch-2.7.1 CPU (Apple M1)
# ...

# %%
from IPython.display import Image

# %%
Image("runs/detect/train2/confusion_matrix.png")

# %%
Image("runs/detect/train2/results.png")

# %%
import os

model = YOLO("runs/detect/train2/weights/best.pt")  # load a custom model
#model = YOLO("yolo11n-seg.pt")  
results = model.predict(source=os.getcwd() + "/YOLO_data/train/images/14.png", save=True)
results[0].show()  # show results
# Out:
# image 1/1 /Users/skowronek/Documents/WormAnalysis/notebooks/YOLO_data/train/images/14.png: 1024x1024 1 Worm, 376.2ms
# Speed: 3.8ms preprocess, 376.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to runs/detect/predict17

# %%
results = model.predict(source=os.getcwd() + "/YOLO_data/val/images/28.jpg", save=True)
results[0].show()  # show results
# Out:
# image 1/1 /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/V2/YOLO_data/val/images/28.jpg: 1024x1024 4 Worms, 498.8ms
# Speed: 5.7ms preprocess, 498.8ms inference, 1.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/runs/detect/predict

# %%
results = model.predict(source=os.getcwd() + "/YOLO_data/train/images/3.jpg", save=True)
results[0].show()  # show results
# Out:
# image 1/1 /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/V2/YOLO_data/train/images/3.jpg: 1024x1024 4 Worms, 441.3ms
# Speed: 5.7ms preprocess, 441.3ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/runs/detect/predict

# %%
results = model.predict(source=os.getcwd() + "/YOLO_data/train/images/7.jpg", save=True)
results[0].show()  # show results
# Out:
# image 1/1 /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/V2/YOLO_data/train/images/7.jpg: 1024x1024 10 Worms, 450.6ms
# Speed: 5.7ms preprocess, 450.6ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/runs/detect/predict

# %%
results = model.predict(source=os.getcwd() + "/YOLO_data/train/images/10.jpg", save=True)
results[0].show()  # show results
# Out:
# image 1/1 /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/V2/YOLO_data/train/images/10.jpg: 1024x1024 1 Worm, 446.2ms
# Speed: 5.7ms preprocess, 446.2ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/runs/detect/predict

# %%
results = model.predict(source=os.getcwd() + "/YOLO_data/train/images/14.jpg", save=True)
results[0].show()  # show results
# Out:
# image 1/1 /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/V2/YOLO_data/train/images/14.jpg: 1024x1024 10 Worms, 436.5ms
# Speed: 5.9ms preprocess, 436.5ms inference, 1.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/runs/detect/predict

# %%
results = model.predict(source=os.getcwd() + "/YOLO_data/val/images/30.jpg", save=True)
results[0].show()  # show results
# Out:
# image 1/1 /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/V2/YOLO_data/val/images/30.jpg: 1024x1024 7 Worms, 440.9ms
# Speed: 5.8ms preprocess, 440.9ms inference, 0.9ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/runs/detect/predict

# %%
results = model.predict(source=os.getcwd() + "/YOLO_data/val/images/34.jpg", save=True)
results[0].show()  # show results
# Out:
# image 1/1 /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/V2/YOLO_data/val/images/34.jpg: 1024x1024 4 Worms, 442.7ms
# Speed: 5.4ms preprocess, 442.7ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/runs/detect/predict

# %%
results = model.predict(source=os.getcwd() + "/YOLO_data/val/images/62.jpg", save=True)
results[0].show()  # show results
# Out:
# image 1/1 /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/V2/YOLO_data/val/images/62.jpg: 1024x1024 2 Worms, 448.3ms
# Speed: 5.6ms preprocess, 448.3ms inference, 1.0ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/runs/detect/predict
