# %%
# !pip install ultralytics==8.3.127 roboflow torch==2.0.1 torchvision==0.15.2 torchaudio==2.0.1
# Out:
# /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/V2/.venv/bin/pip: line 2: /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/.venv/bin/python: No such file or directory
# /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/V2/.venv/bin/pip: line 2: exec: /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/.venv/bin/python: cannot execute: No such file or directory

# %%
# !pip install torchvision==0.15.2
# Out:
# /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/V2/.venv/bin/pip: line 2: /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/.venv/bin/python: No such file or directory
# /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/V2/.venv/bin/pip: line 2: exec: /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/.venv/bin/python: cannot execute: No such file or directory

# %%
import torch
import torchvision

print("Torch version:", torch.__version__)
print("Torchvision version:", torchvision.__version__)
# Out:
# Torch version: 2.7.1
# Torchvision version: 0.22.1

# %%
from ultralytics import YOLO

# %%
from ultralytics import YOLO
import os

#model = YOLO("yolo11n-seg.pt")  
#model = YOLO("../V2/runs6/segment/train/weights/best.pt")
model = YOLO("../models/YOLO_segmentation.pt")

current_directory = os.getcwd()
train_results = model.train(
    data = current_directory + "/YOLO_data/data.yaml",
    epochs=100,
    imgsz=1024,
    device="cpu",
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.235 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.170 🚀 Python-3.13.5 torch-2.7.1 CPU (Apple M1)
# ...

# %%
from IPython.display import Image

# %%
Image("runs/segment/train/confusion_matrix.png")

# %%
Image("runs/segment/train/results.png")

# %%
import os

model = YOLO("runs/segment/train/weights/best.pt")  # load a custom model
#model = YOLO("yolo11n-seg.pt")  
results = model.predict("YOLO_data/train/images/Mut_20251114_160022.png", save=True)
results[0].show()  # show results
# Out:
# image 1/1 /Users/skowronek/Documents/WormAnalysis/notebooks/YOLO_data/train/images/Mut_20251114_160022.png: 1024x1024 3 Worms, 276.2ms
# Speed: 7.1ms preprocess, 276.2ms inference, 10.2ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to runs/segment/predict

# %%
results = model.predict(source=os.getcwd() + "/YOLO_data/test/images/WTPHX652-11.png", save=True)
results[0].show()  # show results
# Out:
# image 1/1 /Users/skowronek/Documents/WormAnalysis/notebooks/YOLO_data/test/images/WTPHX652-11.png: 1024x1024 2 Worms, 233.4ms
# Speed: 4.2ms preprocess, 233.4ms inference, 4.8ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to runs/segment/predict

# %%
results = model.predict(source=os.getcwd() + "/YOLO_data/test/images/27_down.jpg", save=True)
results[0].show()  # show results
# Out:
# image 1/1 /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/V2/YOLO_data/test/images/27_down.jpg: 1024x1024 3 Worms, 313.4ms
# Speed: 3.5ms preprocess, 313.4ms inference, 5.2ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/runs/segment/predict

# %%
results = model.predict(source=os.getcwd() + "/YOLO_data/test/images/24_up.jpg", save=True)
results[0].show()  # show results
# Out:
# image 1/1 /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/V2/YOLO_data/test/images/24_up.jpg: 1024x1024 2 Worms, 279.0ms
# Speed: 3.7ms preprocess, 279.0ms inference, 3.9ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/runs/segment/predict

# %%
results = model.predict(source=os.getcwd() + "/YOLO_data/test/images/23_up.jpg", save=True)
results[0].show()  # show results
# Out:
# image 1/1 /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/V2/YOLO_data/test/images/23_up.jpg: 1024x1024 1 Worm, 276.7ms
# Speed: 4.5ms preprocess, 276.7ms inference, 3.9ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/runs/segment/predict

# %%
results = model.predict(source=os.getcwd() + "/YOLO_data/val/images/18_up.jpg", save=True)
results[0].show()  # show results
# Out:
# image 1/1 /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/V2/YOLO_data/val/images/18_up.jpg: 1024x1024 2 Worms, 279.4ms
# Speed: 4.5ms preprocess, 279.4ms inference, 5.6ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/runs/segment/predict

# %%
results = model.predict(source=os.getcwd() + "/YOLO_data/val/images/19_up.jpg", save=True)
results[0].show()  # show results
# Out:
# image 1/1 /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/V2/YOLO_data/val/images/19_up.jpg: 1024x1024 3 Worms, 334.1ms
# Speed: 9.3ms preprocess, 334.1ms inference, 5.0ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/runs/segment/predict

# %%
results = model.predict(source=os.getcwd() + "/YOLO_data/val/images/21_up.jpg", save=True)
results[0].show()  # show results
# Out:
# image 1/1 /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/V2/YOLO_data/val/images/21_up.jpg: 1024x1024 4 Worms, 276.8ms
# Speed: 4.6ms preprocess, 276.8ms inference, 5.7ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to /Users/skowronek/Documents/Detection des synapses anormaux/DetectionSynapsesAnormaux/runs/segment/predict
